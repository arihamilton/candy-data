# %%
import pandas as pd

# %%
data = pd.read_csv('candy-data.csv')

# %%
import matplotlib.pyplot as plt

# %%
data.plot(x="competitorname", y = "winpercent", kind="bar")

# %%
data.plot(x="competitorname", y = "winpercent", kind="barh")
